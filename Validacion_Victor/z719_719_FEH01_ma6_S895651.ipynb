# %% [markdown]
# # 6 WorkFlow Gerencial, futuro=SEP — versión Google Cloud / Jupyter

# %% [markdown]
# > **VERSIÓN 719_FEH01_ma6 — VÍCTOR**
# >
# > Esta versión conserva el workflow validado de la corrida **719_FEH01_ma6**:
# > FE intra-mes (#03 Grupo B) + GA con `gramEvol` (#10 Grupo A) +
# > FE histórico (#05 Grupo B) + training 100% (#12) +
# > Grid Search + Final Training.
# >
# > Está preparada para ejecutarse completa con **Run All**.
# >
# > **Configuración de esta corrida:**
# > - semilla: `895651`
# > - training: `100%`
# > - único cambio experimental: FEhist agrega ma6 manteniendo ma3
# > - Kaggle: envío automático habilitado (`submit_kaggle = TRUE`)
# >
# > Al finalizar, genera y envía los 11 cortes (`800, 850, ..., 1300`).

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2 Seteo del ambiente en Google Cloud / Jupyter
#
# Esta variante conserva el workflow Gerencial original y cambia únicamente la preparación del ambiente.
#
# - No monta Google Drive.
# - Trabaja directamente sobre el disco persistente de la VM.
# - Se ejecuta con kernel **R** desde el inicio.
# - Las rutas se concentran en variables para evitar referencias a `/content/...` propias de Colab.

# %%
# ============================================================
# RUTAS DE TRABAJO - GOOGLE CLOUD / JUPYTER
# ============================================================
# Si la VM usa otra ubicación, alcanza con cambiar estas variables
# o definir DM_BUCKET / DM_DATASETS_DIR / DM_EXP_DIR en el entorno.

BASE_BUCKET <- Sys.getenv("DM_BUCKET", unset = "/home/ds/buckets/b1")
DATASETS_DIR <- Sys.getenv("DM_DATASETS_DIR", unset = file.path(BASE_BUCKET, "datasets"))
EXP_DIR <- Sys.getenv("DM_EXP_DIR", unset = file.path(BASE_BUCKET, "exp"))

dir.create(DATASETS_DIR, recursive = TRUE, showWarnings = FALSE)
dir.create(EXP_DIR, recursive = TRUE, showWarnings = FALSE)

cat("BASE_BUCKET :", BASE_BUCKET, "\n")
cat("DATASETS_DIR:", DATASETS_DIR, "\n")
cat("EXP_DIR     :", EXP_DIR, "\n")
# Out:
# BASE_BUCKET : /home/ds/buckets/b1
# DATASETS_DIR: /home/ds/buckets/b1/datasets
# EXP_DIR     : /home/ds/buckets/b1/exp

# %% [markdown]
# #### Descarga de datasets si todavía no existen en la VM
#
# El notebook original los copia entre Google Drive y `/content`. En Cloud no hace falta duplicarlos: se guardan directamente en `DATASETS_DIR`.

# %%
# Descarga solamente si el archivo todavía no está presente
URL_ORIGEN <- "https://storage.googleapis.com/open-courses/itba2026-7c9a/dm/"

descargar_si_falta <- function(archivo) {
  destino <- file.path(DATASETS_DIR, archivo)
  if (!file.exists(destino)) {
    cat("Descargando", archivo, "...\n")
    download.file(paste0(URL_ORIGEN, archivo), destino, mode = "wb", quiet = FALSE)
  } else {
    cat("Ya existe:", destino, "\n")
  }
}

descargar_si_falta("dataset_pequeno.csv")
descargar_si_falta("gerencial_competencia_2026.csv.gz")
# Out:
# Ya existe: /home/ds/buckets/b1/datasets/dataset_pequeno.csv
# Ya existe: /home/ds/buckets/b1/datasets/gerencial_competencia_2026.csv.gz

# %% [markdown]
# #### PASO 1 — Control de Kaggle (NO envía nada)
#
# Este control se ejecuta al principio del notebook.
#
# Verifica:
#
# - que exista la CLI de Kaggle;
# - que exista `~/.kaggle/kaggle.json`;
# - que la cuenta configurada tenga acceso a la competencia real
#   **`utn-2026-virtual-mgr`**.
#
# Si termina con `CONTROL KAGGLE OK`, se puede dejar correr el resto del notebook.
# **Esta celda no hace ningún submit.**

# %%
# ================================================================
# PASO 1 - CONTROL DE ACCESO A KAGGLE
# SOLO LECTURA: NO HACE SUBMIT
# ================================================================

competencia_control <- "utn-2026-virtual-mgr"

kaggle_cmd <- Sys.which("kaggle")
kaggle_json <- path.expand("~/.kaggle/kaggle.json")

cat("Kaggle CLI :", ifelse(nchar(kaggle_cmd) > 0, kaggle_cmd, "NO ENCONTRADO"), "\n")
cat("kaggle.json:", ifelse(file.exists(kaggle_json), kaggle_json, "NO ENCONTRADO"), "\n")
cat("Competencia:", competencia_control, "\n")

if (nchar(kaggle_cmd) == 0)
  stop("CONTROL KAGGLE: no se encontró el comando kaggle en el PATH.")

if (!file.exists(kaggle_json))
  stop("CONTROL KAGGLE: no se encontró ~/.kaggle/kaggle.json.")

salida_control <- suppressWarnings(
  system2(
    kaggle_cmd,
    args = c(
      "competitions", "submissions",
      "-c", competencia_control,
      "--page-size", "1",
      "--csv",
      "--quiet"
    ),
    stdout = TRUE,
    stderr = TRUE
  )
)

estado_control <- attr(salida_control, "status")
if (is.null(estado_control)) estado_control <- 0

if (estado_control != 0) {
  cat(paste(salida_control, collapse = "\n"), "\n")
  stop(
    "CONTROL KAGGLE: no se pudo acceder a la competencia ",
    competencia_control,
    ". Revisar cuenta, token o acceso."
  )
}

cat("\n============================================================\n")
cat("CONTROL KAGGLE OK\n")
cat("Acceso confirmado a:", competencia_control, "\n")
cat("NO se realizó ningún submit.\n")
cat("============================================================\n")
# Out:
# Kaggle CLI : /home/ds/.venv/bin/kaggle
# kaggle.json: /home/ds/.kaggle/kaggle.json
# Competencia: utn-2026-virtual-mgr
#
# ============================================================
# CONTROL KAGGLE OK
# Acceso confirmado a: utn-2026-virtual-mgr
# NO se realizó ningún submit.
# ============================================================

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta versión Cloud/Jupyter se ejecuta con kernel **R** desde el comienzo. No es necesario cambiar de runtime.

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Sep 19 16:29:40 2026"

# %%
# limpio la memoria, PERO conservo las rutas de trabajo de Cloud
# porque fueron definidas antes y se usan más adelante.
objetos_a_conservar <- c("BASE_BUCKET", "DATASETS_DIR", "EXP_DIR")

rm(
  list = setdiff(
    ls(all.names = TRUE),
    objetos_a_conservar
  )
)

gc(full = TRUE, verbose = FALSE) # garbage collection

# control: las rutas deben seguir existiendo después de limpiar memoria
stopifnot(
  exists("BASE_BUCKET"),
  exists("DATASETS_DIR"),
  exists("EXP_DIR")
)

cat("Rutas conservadas después de limpiar memoria:\n")
cat("BASE_BUCKET :", BASE_BUCKET, "\n")
cat("DATASETS_DIR:", DATASETS_DIR, "\n")
cat("EXP_DIR     :", EXP_DIR, "\n")
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  673360 36.0 1479497    79.1 1479497  79.1
# Vcells 1247987  9.6 8388608    64.0 2180579  16.7
# Rutas conservadas después de limpiar memoria:
# BASE_BUCKET : /home/ds/buckets/b1
# DATASETS_DIR: /home/ds/buckets/b1/datasets
# EXP_DIR     : /home/ds/buckets/b1/exp

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 895651

PARAM$experimento <- "719_FEH01"
PARAM$dataset <- "gerencial_competencia_2026.csv.gz"


# ================================================================
# PROBLEMA #10 - GRUPO A
# Feature Engineering intra-mes mediante Algoritmo Genético (gramEvol)
# Adaptado desde 620_WorkFlow_01_junior_exp10_grupoA.ipynb
# ================================================================
PARAM$GA <- list(
  popSize = 150,               # población
  iterations = 50,             # generaciones
  top_features = 20,           # features GA a inyectar
  max_terminales = 60,         # máximo de variables terminales
  seqLen = 250,                # longitud máxima del genoma
  max.depth = 10,              # profundidad máxima BNF
  max_filas_fitness = 50000,   # muestra máxima para fitness

  # Valores que realmente ejecuta el notebook del Grupo A
  mutationChance = 0.15,
  elitism_fraction = 0.50
)


# ================================================================
# KAGGLE - MODO AUTOMATICO PARA ESTA CORRIDA
# TRUE = al llegar al PASO 2 genera y envía los 11 submissions.
# ================================================================
PARAM$control <- list()
PARAM$control$submit_kaggle <- TRUE

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd(EXP_DIR)
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd(file.path(EXP_DIR, experimento_folder))

# dejo visible la carpeta efectiva del experimento
cat("Experimento:", getwd(), "\n")
# Out:
# Experimento: /home/ds/buckets/b1/exp/WF719_LGBM01

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
archivo_dataset <- file.path(DATASETS_DIR, PARAM$dataset)
stopifnot(file.exists(archivo_dataset))
dataset <- fread(archivo_dataset)
cat("Dataset:", archivo_dataset, "\n")
cat("Filas:", nrow(dataset), " Columnas:", ncol(dataset), "\n")
# Out:
# Dataset: /home/ds/buckets/b1/datasets/gerencial_competencia_2026.csv.gz
# Filas: 219110  Columnas: 32

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# ================================================================
# 6.3.1.3 FE_intra_manual
# Recomendación elegida: PROBLEMA #03 - GRUPO B - EXPERIMENTO 2
# Flags + Z-Score + ratios no redundantes
# Adaptado al z719 final Gerencial - futuro 202109
# ================================================================


# Verifica que existan todas las variables necesarias
atributos_presentes <- function(patributos)
{
  atributos <- unique(patributos)
  comun <- intersect(atributos, colnames(dataset))

  return(length(atributos) == length(comun))
}


# ------------------------------------------------
# División segura
# Si el denominador es 0, lo convierte en NA
# ------------------------------------------------
divseg <- function(numerador, denominador)
{
  denominador[denominador == 0] <- NA
  return(numerador / denominador)
}


# ================================================================
# VARIABLES ORIGINALES DEL z719
# ================================================================

# Mes: 1, 2, ..., 12
if(atributos_presentes(c("foto_mes")))
  dataset[, kmes := foto_mes %% 100]


# Variable original del workflow
if(atributos_presentes(c("mpayroll", "cliente_edad")))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]


# ================================================================
# EXPERIMENTO 2 - GRUPO B
# ================================================================

# 10 variables utilizadas por el Grupo B
vars_top10 <- c(
  "ctrx_quarter",
  "mcaja_ahorro",
  "cpayroll_trx",
  "mcuentas_saldo",
  "mcuenta_corriente",
  "mprestamos_personales",
  "mtarjeta_visa_consumo",
  "Visa_mpagominimo",
  "cliente_edad",
  "mpasivos_margen"
)


# Variables que pueden presentar ceros por no tener el producto
vars_alto_riesgo <- c(
  "cpayroll_trx",
  "mcuenta_corriente",
  "mprestamos_personales",
  "Visa_mpagominimo"
)


# ================================================================
# A) FLAGS DE TENENCIA
# ================================================================

if(atributos_presentes(vars_alto_riesgo))
{
  for(v in vars_alto_riesgo)
  {
    nombre_flag <- paste0("flag_tiene_", v)

    dataset[, (nombre_flag) := as.integer(get(v) > 0)]
  }
}


# ================================================================
# B) Z-SCORE
#
# IMPORTANTE:
# Grupo B calculaba media y desvío SOLO con su training.
#
# Como nuestro z719 final usa:
# training   = 202005 ... 202106
# validation = 202107
# future     = 202109
#
# calculamos media y SD SOLO con 202005 ... 202106.
# Así evitamos usar información de validation/future.
# ================================================================

if(atributos_presentes(vars_top10))
{
  filas_estandarizacion <- dataset[
    foto_mes %in% c(
      202005, 202006, 202007, 202008, 202009, 202010,
      202011, 202012,
      202101, 202102, 202103, 202104, 202105, 202106
    )
  ]

  for(v in vars_top10)
  {
    # Media calculada solamente con training
    media_v <- mean(
      filas_estandarizacion[[v]],
      na.rm = TRUE
    )

    # Desvío estándar calculado solamente con training
    desvio_v <- sd(
      filas_estandarizacion[[v]],
      na.rm = TRUE
    )

    # Nombre de la nueva variable
    nombre_z <- paste0("z_", v)

    # Creo Z-Score solo si el desvío es válido
    if(is.finite(desvio_v) && desvio_v > 0)
    {
      dataset[, (nombre_z) := (get(v) - media_v) / desvio_v]
    }
    else
    {
      dataset[, (nombre_z) := NA_real_]
    }

    # Muestro los parámetros utilizados
    cat(sprintf(
      "Estandarizada %s | media training = %.6f | sd training = %.6f\n",
      v, media_v, desvio_v
    ))
  }

  # Libero tabla temporal
  rm(filas_estandarizacion)
}


# ================================================================
# C) RATIOS NO REDUNDANTES
#
# 10 variables => 45 pares únicos
# Se genera A/B, pero NO además B/A.
# ================================================================

vars_z_top10 <- paste0("z_", vars_top10)

if(atributos_presentes(vars_z_top10))
{
  n_vars <- length(vars_z_top10)

  for(i in 1:(n_vars - 1))
  {
    for(j in (i + 1):n_vars)
    {
      num <- vars_z_top10[i]
      den <- vars_z_top10[j]

      nombre_nueva <- paste0(
        "ratio_",
        vars_top10[i],
        "_sobre_",
        vars_top10[j],
        "_z"
      )

      dataset[, (nombre_nueva) := divseg(
        get(num),
        get(den)
      )]
    }
  }
}
# Out:
# Estandarizada ctrx_quarter | media training = 109.338012 | sd training = 82.629953
# Estandarizada mcaja_ahorro | media training = 72691.194467 | sd training = 211995.191241
# Estandarizada cpayroll_trx | media training = 0.972505 | sd training = 1.436290
# Estandarizada mcuentas_saldo | media training = 211390.002657 | sd training = 1419830.099872
# Estandarizada mcuenta_corriente | media training = 2915.745202 | sd training = 68215.144598
# Estandarizada mprestamos_personales | media training = 28474.800457 | sd training = 93758.559899
# Estandarizada mtarjeta_visa_consumo | media training = 28819.712502 | sd training = 48848.121328
# Estandarizada Visa_mpagominimo | media training = 5182.464341 | sd training = 17027.906327
# Estandarizada cliente_edad | media training = 46.742161 | sd training = 12.972640
# Estandarizada mpasivos_margen | media training = 1474.372185 | sd training = 4465.858059

# %%
# ================================================================
# CONTROL 1 - FE INTRA-MES
# No modifica datos: solamente verifica que se hayan creado
# las variables esperadas del Experimento 2 del Grupo B.
# ================================================================

flags_esperados <- paste0("flag_tiene_", vars_alto_riesgo)
z_esperados <- paste0("z_", vars_top10)

faltan_flags <- setdiff(flags_esperados, colnames(dataset))
faltan_z <- setdiff(z_esperados, colnames(dataset))
ratios_creados <- grep("^ratio_.*_z$", colnames(dataset), value = TRUE)

if (length(faltan_flags) > 0)
  stop("CONTROL FE intra-mes: faltan flags: ", paste(faltan_flags, collapse = ", "))

if (length(faltan_z) > 0)
  stop("CONTROL FE intra-mes: faltan variables Z-Score: ", paste(faltan_z, collapse = ", "))

if (length(ratios_creados) < 45)
  stop("CONTROL FE intra-mes: se esperaban al menos 45 ratios y se encontraron ", length(ratios_creados))

cat(
  "CONTROL FE intra-mes OK | filas:", nrow(dataset),
  "| columnas:", ncol(dataset),
  "| flags:", length(flags_esperados),
  "| z-score:", length(z_esperados),
  "| ratios:", length(ratios_creados), "\n"
)
# Out:
# CONTROL FE intra-mes OK | filas: 219110 | columnas: 93 | flags: 4 | z-score: 10 | ratios: 45

# %% [markdown]
# #### 6.3.1.3.2 FE_intra_GA — Problema #10, Grupo A
#
# **Decisión elegida:** incorporar Feature Engineering intra-mes mediante
# Algoritmo Genético con `gramEvol`, adaptando el bloque del notebook
# `620_WorkFlow_01_junior_exp10_grupoA.ipynb` al `z719` Gerencial.
#
# Este bloque se ejecuta después del FE intra-mes del Problema #03 y antes
# de FEhist, para que las variables `GA_Feature_*` también puedan recibir
# lags, deltas y media móvil en el bloque histórico.
#
# **Importante:** se conserva la lógica ejecutable del notebook del Grupo A.
# La población, generaciones, top features, terminales, `seqLen` y `max.depth`
# son los del archivo fuente. Los parámetros de presión selectiva que realmente
# ejecuta ese notebook son `mutationChance = 0.15` y `elitism = 50%` de la población.

# %%
# ==============================================================================
# 6.3.1.3.2 FE_intra_GA: Algoritmo Genético (Grammatical Evolution)
# ==============================================================================

if (!require("gramEvol")) {
  install.packages("gramEvol", repos = "https://cloud.r-project.org", dependencies = TRUE)
}
if (!require("gramEvol")) {
  install.packages("gramEvol", repos = "https://cran.rstudio.com", dependencies = TRUE)
}
require("gramEvol")

if (!require("lightgbm")) {
  install.packages("lightgbm", repos = "https://cloud.r-project.org")
}
require("lightgbm")
require("data.table")
require("parallel")

if (is.null(PARAM$GA)) {
  PARAM$GA <- list(
    popSize = 150,
    iterations = 50,
    top_features = 20,
    max_terminales = 60,
    seqLen = 250,
    max.depth = 10,
    max_filas_fitness = 50000,
    mutationChance = 0.15,
    elitism_fraction = 0.50
  )
}

# carpeta efectiva del experimento actual
dir_experimento_base <- getwd()

# 1. Variables candidatas para el Algoritmo Genético
excluir_GA <- c("numero_de_cliente", "foto_mes", "clase_ternaria", "clase01", "azar", "fold_train", "fold_final_train")
candidatas_GA <- setdiff(colnames(dataset), excluir_GA)

# Filtrar únicamente variables numéricas
son_numericas <- sapply(dataset[, candidatas_GA, with = FALSE], is.numeric)
candidatas_GA <- candidatas_GA[son_numericas]

# Excluir fechas
patron_fechas <- "^(f|.*_f|.*fecha)"
candidatas_GA <- candidatas_GA[!grepl(patron_fechas, candidatas_GA, ignore.case = TRUE)]

# Límite de seguridad de terminales para controlar el espacio de búsqueda
MAX_TERMINALES <- if (!is.null(PARAM$GA$max_terminales)) PARAM$GA$max_terminales else 60
if (length(candidatas_GA) > MAX_TERMINALES) {
  set.seed(PARAM$semilla_primigenia)
  candidatas_GA <- sample(candidatas_GA, MAX_TERMINALES)
}

cat("Variables candidatas para Grammatical Evolution:", length(candidatas_GA), "\n")

# 2. Split Local de Validación (sin tocar 202107 ni 202109)
meses_disponibles <- sort(unique(dataset$foto_mes[dataset$foto_mes < 202107]))
meses_val_GA <- tail(meses_disponibles, 3)
meses_tr_GA  <- setdiff(meses_disponibles, meses_val_GA)

idx_tr_all <- which(dataset$foto_mes %in% meses_tr_GA)
idx_val_all <- which(dataset$foto_mes %in% meses_val_GA)

# Subsampling controlado para evaluación de fitness ultrarrápida
set.seed(PARAM$semilla_primigenia)
n_fit <- if (!is.null(PARAM$GA$max_filas_fitness)) PARAM$GA$max_filas_fitness else 50000
idx_tr_GA <- if (length(idx_tr_all) > n_fit) sample(idx_tr_all, n_fit) else idx_tr_all
idx_val_GA <- if (length(idx_val_all) > (n_fit / 2)) sample(idx_val_all, n_fit / 2) else idx_val_all

y_tr_GA <- ifelse(dataset$clase_ternaria[idx_tr_GA] %in% c("BAJA+1", "BAJA+2"), 1L, 0L)
y_val_GA <- ifelse(dataset$clase_ternaria[idx_val_GA] %in% c("BAJA+1", "BAJA+2"), 1L, 0L)

# 3. Operadores Protegidos
protected_div <- function(x, y) {
  res <- x / (y + 1e-5)
  res[is.na(res) | is.infinite(res)] <- 0
  res
}

protected_log_diff <- function(x, y) {
  res <- log(abs(x - y) + 1)
  res[is.na(res) | is.infinite(res)] <- 0
  res
}

es_expresion_trivial <- function(f) {
  !grepl("[+*/-]|protected_", f)
}

# 4. Definición de la Gramática BNF
string_vars <- paste(candidatas_GA, collapse = " | ")
rule_text <- paste0(
  "<expr> ::= <op>\n",
  "<op>   ::= <op> + <op> | <op> - <op> | <op> * <op> | ",
  "protected_div(<op>, <op>) | protected_log_diff(<op>, <op>) | <var>\n",
  "<var>  ::= ", string_vars
)

tf <- tempfile()
writeLines(rule_text, tf)
bnf_grammar <- CreateGrammar(tf)
unlink(tf)

# 5. Función de Fitness con LightGBM Univariado Real
fitness_gramEvol <- function(expr) {
  valores <- tryCatch(eval(expr, envir = dataset), error = function(e) NULL)
  if (is.null(valores)) return(1)

  val_tr <- valores[idx_tr_GA]
  val_finitos <- val_tr[is.finite(val_tr)]
  if (length(val_finitos) == 0 || length(unique(val_finitos)) <= 1) {
    return(1)
  }

  dtr_ga  <- lgb.Dataset(data = matrix(val_tr, ncol = 1), label = y_tr_GA, free_raw_data = TRUE)
  dval_ga <- lgb.Dataset(data = matrix(valores[idx_val_GA], ncol = 1), label = y_val_GA, free_raw_data = TRUE)

  modelo_ga <- tryCatch({
    lgb.train(
      params = list(objective = "binary", metric = "auc",
                    learning_rate = 0.1, num_threads = 1, verbosity = -1),
      data = dtr_ga, valids = list(valid = dval_ga),
      nrounds = 50, early_stopping_rounds = 10, verbose = -1
    )
  }, error = function(e) NULL)

  if (is.null(modelo_ga) || is.null(modelo_ga$best_score) || is.na(modelo_ga$best_score)) return(1)

  1 - modelo_ga$best_score
}

evaluar_genoma <- function(genoma) {
  expr_obj <- tryCatch(suppressWarnings(GrammarMap(genoma, bnf_grammar)), error = function(e) NULL)
  if (is.null(expr_obj) || !isTRUE(GrammarIsTerminal(expr_obj))) {
    return(list(score = 0, formula = NA_character_))
  }
  expr_lang <- tryCatch(as.expression(expr_obj), error = function(e) NULL)
  if (is.null(expr_lang) || length(expr_lang) == 0) {
    return(list(score = 0, formula = NA_character_))
  }

  expr_final  <- expr_lang[[1]]
  formula_str <- paste(deparse(expr_final, width.cutoff = 500L), collapse = " ")
  costo <- fitness_gramEvol(expr_final)
  auc   <- 1 - costo

  list(score = auc, formula = formula_str)
}

# 6. Ejecución del Algoritmo Genético
set.seed(PARAM$semilla_primigenia)

cat("\n===================================================================\n")
cat(">>> INICIANDO GRAMMATICAL EVOLUTION (gramEvol) <<<\n")
cat("===================================================================\n")

ge_res <- GrammaticalEvolution(
  grammarDef      = bnf_grammar,
  evalFunc        = fitness_gramEvol,
  popSize         = PARAM$GA$popSize,
  iterations      = PARAM$GA$iterations,
  terminationCost = 0.10,
  seqLen          = PARAM$GA$seqLen,
  max.depth       = PARAM$GA$max.depth,
  
  # Nuevos parámetros de presión selectiva
  elitism         = as.integer(PARAM$GA$popSize * PARAM$GA$elitism_fraction),
  mutationChance  = PARAM$GA$mutationChance,
  
  monitorFunc     = function(result) {
    cat(sprintf("Gen %2d | Mejor Costo: %.5f (AUC: %.5f)\n",
                result$population$currentIteration,
                result$best$cost,
                1 - result$best$cost))
  }
)

# 7. Extracción e Inyección del Top N al Dataset
cat("\n=== Evaluando población final para extraer el Top", PARAM$GA$top_features, "===\n")

pop_matrix      <- ge_res$population$population
poblacion_final <- split(pop_matrix, row(pop_matrix))

n_cores <- max(1, detectCores() - 1)
resultados <- if (.Platform$OS.type == "unix") {
  mclapply(poblacion_final, evaluar_genoma, mc.cores = n_cores)
} else {
  lapply(poblacion_final, evaluar_genoma)
}

scores_finales   <- sapply(resultados, function(r) r$score)
formulas_finales <- sapply(resultados, function(r) r$formula)

ordenados <- order(scores_finales, decreasing = TRUE)

formulas_vistas <- character()
ga_cols_creadas <- character()
top_guardados   <- 0
idx             <- 1

dt_trazabilidad <- data.table(Variable=character(), AUC=numeric(), Formula=character())

while (top_guardados < PARAM$GA$top_features && idx <= length(ordenados)) {
  i <- ordenados[idx]
  idx <- idx + 1

  if (is.na(scores_finales[i]) || scores_finales[i] <= 0.50) next
  if (is.na(formulas_finales[i]) || formulas_finales[i] %in% formulas_vistas) next
  if (es_expresion_trivial(formulas_finales[i])) next

  eval_res <- tryCatch(
    eval(parse(text = formulas_finales[i])[[1]], envir = dataset),
    error = function(e) NULL
  )
  if (is.null(eval_res) || length(unique(eval_res[is.finite(eval_res)])) <= 1) next

  top_guardados <- top_guardados + 1
  formulas_vistas <- c(formulas_vistas, formulas_finales[i])

  nombre_col <- paste0("GA_Feature_", top_guardados)
  ga_cols_creadas <- c(ga_cols_creadas, nombre_col)

  cat(sprintf("[%s] AUC Univariado: %.5f | Fórmula: %s\n", nombre_col, scores_finales[i], formulas_finales[i]))
  dataset[, (nombre_col) := eval_res]
  dt_trazabilidad <- rbind(dt_trazabilidad, list(nombre_col, scores_finales[i], formulas_finales[i]))
}

fwrite(dt_trazabilidad, file = file.path(dir_experimento_base, paste0("GA_trazabilidad_formulas_s", PARAM$semilla_primigenia, ".csv")), sep = ",")
cat("\nArchivo de trazabilidad guardado en: GA_trazabilidad_formulas_s", PARAM$semilla_primigenia, ".csv\n")

cat("\nColumnas generadas por Algoritmo Genético e inyectadas al dataset:", paste(ga_cols_creadas, collapse = ", "), "\n")

# Blindaje anti-leakage: asegura que clase01 no quede en dataset antes de FEhist
if ("clase01" %in% colnames(dataset)) dataset[, clase01 := NULL]
# Out:
# Loading required package: gramEvol
#
# Loading required package: lightgbm
#
# Loading required package: parallel
# Variables candidatas para Grammatical Evolution: 60
#
# ===================================================================
# >>> INICIANDO GRAMMATICAL EVOLUTION (gramEvol) <<<
# ===================================================================
# Gen  1 | Mejor Costo: 0.16862 (AUC: 0.83138)
# Gen  2 | Mejor Costo: 0.16862 (AUC: 0.83138)
# Gen  3 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen  4 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen  5 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen  6 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen  7 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen  8 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen  9 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 10 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 11 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 12 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 13 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 14 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 15 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 16 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 17 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 18 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 19 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 20 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 21 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 22 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 23 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 24 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 25 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 26 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 27 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 28 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 29 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 30 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 31 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 32 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 33 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 34 | Mejor Costo: 0.14300 (AUC: 0.85700)
# Gen 35 | Mejor Costo: 0.13785 (AUC: 0.86215)
# Gen 36 | Mejor Costo: 0.13785 (AUC: 0.86215)
# Gen 37 | Mejor Costo: 0.13785 (AUC: 0.86215)
# Gen 38 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 39 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 40 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 41 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 42 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 43 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 44 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 45 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 46 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 47 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 48 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 49 | Mejor Costo: 0.13312 (AUC: 0.86688)
# Gen 50 | Mejor Costo: 0.13312 (AUC: 0.86688)
#
# === Evaluando población final para extraer el Top 20 ===
# [GA_Feature_1] AUC Univariado: 0.86688 | Fórmula: protected_log_diff(ratio_mcaja_ahorro_sobre_cpayroll_trx_z, mpayroll)
# [GA_Feature_2] AUC Univariado: 0.80247 | Fórmula: ratio_mcaja_ahorro_sobre_mprestamos_personales_z - ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z
# [GA_Feature_3] AUC Univariado: 0.76986 | Fórmula: ctarjeta_visa_transacciones * ratio_mprestamos_personales_sobre_Visa_mpagominimo_z
# [GA_Feature_4] AUC Univariado: 0.75672 | Fórmula: mactivos_margen - ratio_ctrx_quarter_sobre_cliente_edad_z + mtarjeta_visa_consumo
# [GA_Feature_5] AUC Univariado: 0.70839 | Fórmula: ratio_mcuentas_saldo_sobre_mcuenta_corriente_z - ratio_mprestamos_personales_sobre_Visa_mpagominimo_z
# [GA_Feature_6] AUC Univariado: 0.67276 | Fórmula: mcomisiones + ratio_cpayroll_trx_sobre_mcuenta_corriente_z * ratio_ctrx_quarter_sobre_mprestamos_personales_z
# [GA_Feature_7] AUC Univariado: 0.62313 | Fórmula: protected_log_diff(chomebanking_transacciones, ratio_mcuentas_saldo_sobre_cliente_edad_z) + ratio_ctrx_quarter_sobre_cliente_edad_z
#
# Archivo de trazabilidad guardado en: GA_trazabilidad_formulas_s 895651 .csv
#
# Columnas generadas por Algoritmo Genético e inyectadas al dataset: GA_Feature_1, GA_Feature_2, GA_Feature_3, GA_Feature_4, GA_Feature_5, GA_Feature_6, GA_Feature_7

# %%
# ================================================================
# CONTROL GA - PROBLEMA #10 GRUPO A
# No modifica el dataset: verifica el resultado del bloque gramEvol.
# ================================================================

if (!exists("ga_cols_creadas"))
  stop("CONTROL GA: no existe ga_cols_creadas.")

if (length(ga_cols_creadas) == 0)
  stop("CONTROL GA: no se generó ninguna feature.")

if (anyDuplicated(ga_cols_creadas) > 0)
  stop("CONTROL GA: hay nombres de features duplicados.")

faltan_ga <- setdiff(ga_cols_creadas, colnames(dataset))
if (length(faltan_ga) > 0)
  stop("CONTROL GA: faltan columnas en dataset: ",
       paste(faltan_ga, collapse = ", "))

if ("clase01" %in% colnames(dataset))
  stop("CONTROL GA: clase01 quedó dentro del dataset antes de FEhist.")

if (length(ga_cols_creadas) < PARAM$GA$top_features) {
  warning(
    "CONTROL GA: se solicitaron ",
    PARAM$GA$top_features,
    " features, pero se generaron ",
    length(ga_cols_creadas),
    ". Revisar trazabilidad antes de continuar."
  )
}

cat(
  "CONTROL GA OK | candidatas:", length(candidatas_GA),
  "| features solicitadas:", PARAM$GA$top_features,
  "| features creadas:", length(ga_cols_creadas),
  "| columnas dataset antes de FEhist:", ncol(dataset),
  "\n"
)

print(dt_trazabilidad)
# Out:
# Warning message:
# “CONTROL GA: se solicitaron 20 features, pero se generaron 7. Revisar trazabilidad antes de continuar.”
# CONTROL GA OK | candidatas: 60 | features solicitadas: 20 | features creadas: 7 | columnas dataset antes de FEhist: 100
#        Variable       AUC
#          <char>     <num>
# 1: GA_Feature_1 0.8668755
# 2: GA_Feature_2 0.8024712
# 3: GA_Feature_3 0.7698632
# 4: GA_Feature_4 0.7567198
# 5: GA_Feature_5 0.7083872
# 6: GA_Feature_6 0.6727649
# 7: GA_Feature_7 0.6231295
#                                                                                                                                Formula
#                                                                                                                                 <char>
# 1:                                                               protected_log_diff(ratio_mcaja_ahorro_sobre_cpayroll_trx_z, mpayroll)
# 2:                                 ratio_mcaja_ahorro_sobre_mprestamos_personales_z - ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z
# 3:                                                  ctarjeta_visa_transacciones * ratio_mprestamos_personales_sobre_Visa_mpagominimo_z
# 4:                                                   mactivos_margen - ratio_ctrx_quarter_sobre_cliente_edad_z + mtarjeta_visa_consumo
# 5:                               ratio_mcuentas_saldo_sobre_mcuenta_corriente_z - ratio_mprestamos_personales_sobre_Visa_mpagominimo_z
# 6:                       mcomisiones + ratio_cpayroll_trx_sobre_mcuenta_corriente_z * ratio_ctrx_quarter_sobre_mprestamos_personales_z
# 7: protected_log_diff(chomebanking_transacciones, ratio_mcuentas_saldo_sobre_cliente_edad_z) + ratio_ctrx_quarter_sobre_cliente_edad_z

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "mrentabilidad"
#   [7] "mrentabilidad_annual"
#   [8] "mcomisiones"
#   [9] "mactivos_margen"
#  [10] "mpasivos_margen"
#  [11] "cproductos"
#  [12] "mcuenta_corriente"
#  [13] "mcaja_ahorro"
#  [14] "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"
#  [16] "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"
#  [18] "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"
#  [20] "cpayroll_trx"
#  [21] "mpayroll"
#  [22] "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"
#  [24] "chomebanking_transacciones"
#  [25] "ctrx_quarter"
#  [26] "Master_status"
#  [27] "Master_fechaalta"
#  [28] "Master_mpagominimo"
#  [29] "Visa_status"
#  [30] "Visa_fechaalta"
#  [31] "Visa_mpagominimo"
#  [32] "clase_ternaria"
#  [33] "kmes"
#  [34] "mpayroll_sobre_edad"
#  [35] "flag_tiene_cpayroll_trx"
#  [36] "flag_tiene_mcuenta_corriente"
#  [37] "flag_tiene_mprestamos_personales"
#  [38] "flag_tiene_Visa_mpagominimo"
#  [39] "z_ctrx_quarter"
#  [40] "z_mcaja_ahorro"
#  [41] "z_cpayroll_trx"
#  [42] "z_mcuentas_saldo"
#  [43] "z_mcuenta_corriente"
#  [44] "z_mprestamos_personales"
#  [45] "z_mtarjeta_visa_consumo"
#  [46] "z_Visa_mpagominimo"
#  [47] "z_cliente_edad"
#  [48] "z_mpasivos_margen"
#  [49] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z"
#  [50] "ratio_ctrx_quarter_sobre_cpayroll_trx_z"
#  [51] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z"
#  [52] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z"
#  [53] "ratio_ctrx_quarter_sobre_mprestamos_personales_z"
#  [54] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z"
#  [55] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z"
#  [56] "ratio_ctrx_quarter_sobre_cliente_edad_z"
#  [57] "ratio_ctrx_quarter_sobre_mpasivos_margen_z"
#  [58] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z"
#  [59] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z"
#  [60] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z"
#  [61] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z"
#  [62] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z"
#  [63] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z"
#  [64] "ratio_mcaja_ahorro_sobre_cliente_edad_z"
#  [65] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z"
#  [66] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z"
#  [67] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z"
#  [68] "ratio_cpayroll_trx_sobre_mprestamos_personales_z"
#  [69] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z"
#  [70] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z"
#  [71] "ratio_cpayroll_trx_sobre_cliente_edad_z"
#  [72] "ratio_cpayroll_trx_sobre_mpasivos_margen_z"
#  [73] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z"
#  [74] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z"
#  [75] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z"
#  [76] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z"
#  [77] "ratio_mcuentas_saldo_sobre_cliente_edad_z"
#  [78] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z"
#  [79] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z"
#  [80] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z"
#  [81] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z"
#  [82] "ratio_mcuenta_corriente_sobre_cliente_edad_z"
#  [83] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z"
#  [84] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z"
#  [85] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z"
#  [86] "ratio_mprestamos_personales_sobre_cliente_edad_z"
#  [87] "ratio_mprestamos_personales_sobre_mpasivos_margen_z"
#  [88] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z"
#  [89] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z"
#  [90] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z"
#  [91] "ratio_Visa_mpagominimo_sobre_cliente_edad_z"
#  [92] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z"
#  [93] "ratio_cliente_edad_sobre_mpasivos_margen_z"
#  [94] "GA_Feature_1"
#  [95] "GA_Feature_2"
#  [96] "GA_Feature_3"
#  [97] "GA_Feature_4"
#  [98] "GA_Feature_5"
#  [99] "GA_Feature_6"
# [100] "GA_Feature_7"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# ================================================================
# 6.3.1.5 FEhist - Feature Engineering Histórico
# Recomendación elegida: PROBLEMA #05 - GRUPO B - Exp9112
#
# Variables incorporadas:
#   lag1 + lag2 + lag3
#   delta1 + delta2 + delta3
#   ma3
#   ma6   # <-- único cambio experimental FEH01
#
# Se aplican a todas las variables excepto:
# numero_de_cliente, foto_mes y clase_ternaria
# ================================================================


# Todo es lagueable, menos la primary key, el mes y la clase
cols_lagueables <- copy(setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
))


# ------------------------------------------------
# LAG 1
# valor de la variable un mes atrás
# ------------------------------------------------
dataset[,
    paste0(cols_lagueables, "_lag1") :=
        shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]


# ------------------------------------------------
# LAG 2
# valor de la variable dos meses atrás
# ------------------------------------------------
dataset[,
    paste0(cols_lagueables, "_lag2") :=
        shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]


# ------------------------------------------------
# LAG 3
# valor de la variable tres meses atrás
# ------------------------------------------------
dataset[,
    paste0(cols_lagueables, "_lag3") :=
        shift(.SD, 3, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]


# ------------------------------------------------
# DELTAS
# diferencia entre el valor actual y cada lag
# ------------------------------------------------
for (vcol in cols_lagueables)
{
    dataset[,
        paste0(vcol, "_delta1") :=
            get(vcol) - get(paste0(vcol, "_lag1"))
    ]

    dataset[,
        paste0(vcol, "_delta2") :=
            get(vcol) - get(paste0(vcol, "_lag2"))
    ]

    dataset[,
        paste0(vcol, "_delta3") :=
            get(vcol) - get(paste0(vcol, "_lag3"))
    ]
}


# ------------------------------------------------
# MEDIA MÓVIL DE 3 MESES
# mes actual + dos meses anteriores
# ------------------------------------------------
dataset[,
    paste0(cols_lagueables, "_ma3") :=
        frollmean(
            .SD,
            n = 3,
            align = "right",
            fill = NA,
            na.rm = TRUE
        ),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]


# ------------------------------------------------
# MEDIA MÓVIL DE 6 MESES
# mes actual + cinco meses anteriores
# ÚNICO CAMBIO EXPERIMENTAL FEH01
# ------------------------------------------------
dataset[,
    paste0(cols_lagueables, "_ma6") :=
        frollmean(
            .SD,
            n = 6,
            align = "right",
            fill = NA,
            na.rm = TRUE
        ),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# %%
# ================================================================
# CONTROL 2 - FE HISTÓRICO
# Verifica lag3, delta3, ma3 y ma6 sin modificar el dataset.
# ================================================================

lag3_esperados <- paste0(cols_lagueables, "_lag3")
delta3_esperados <- paste0(cols_lagueables, "_delta3")
ma3_esperados <- paste0(cols_lagueables, "_ma3")
ma6_esperados <- paste0(cols_lagueables, "_ma6")

faltan_lag3 <- setdiff(lag3_esperados, colnames(dataset))
faltan_delta3 <- setdiff(delta3_esperados, colnames(dataset))
faltan_ma3 <- setdiff(ma3_esperados, colnames(dataset))
faltan_ma6 <- setdiff(ma6_esperados, colnames(dataset))

if (length(faltan_lag3) > 0)
  stop("CONTROL FEhist: faltan columnas lag3.")

if (length(faltan_delta3) > 0)
  stop("CONTROL FEhist: faltan columnas delta3.")

if (length(faltan_ma3) > 0)
  stop("CONTROL FEhist: faltan columnas ma3.")

if (length(faltan_ma6) > 0)
  stop("CONTROL FEhist: faltan columnas ma6.")

cat(
  "CONTROL FEhist OK | columnas base lagueables:", length(cols_lagueables),
  "| ma3 creadas:", length(ma3_esperados),
  "| ma6 creadas:", length(ma6_esperados),
  "| columnas totales después de FEhist:", ncol(dataset),
  "| tamaño dataset:", format(object.size(dataset), units = "auto"), "\n"
)
# Out:
# CONTROL FEhist OK | columnas base lagueables: 97 | columnas totales después de FEhist: 779 | tamaño dataset: 1.2 Gb

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 779
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "mrentabilidad"
#   [7] "mrentabilidad_annual"
#   [8] "mcomisiones"
#   [9] "mactivos_margen"
#  [10] "mpasivos_margen"
#  [11] "cproductos"
#  [12] "mcuenta_corriente"
#  [13] "mcaja_ahorro"
#  [14] "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"
#  [16] "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"
#  [18] "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"
#  [20] "cpayroll_trx"
#  [21] "mpayroll"
#  [22] "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"
#  [24] "chomebanking_transacciones"
#  [25] "ctrx_quarter"
#  [26] "Master_status"
#  [27] "Master_fechaalta"
#  [28] "Master_mpagominimo"
#  [29] "Visa_status"
#  [30] "Visa_fechaalta"
#  [31] "Visa_mpagominimo"
#  [32] "clase_ternaria"
#  [33] "kmes"
#  [34] "mpayroll_sobre_edad"
#  [35] "flag_tiene_cpayroll_trx"
#  [36] "flag_tiene_mcuenta_corriente"
#  [37] "flag_tiene_mprestamos_personales"
#  [38] "flag_tiene_Visa_mpagominimo"
#  [39] "z_ctrx_quarter"
#  [40] "z_mcaja_ahorro"
#  [41] "z_cpayroll_trx"
#  [42] "z_mcuentas_saldo"
#  [43] "z_mcuenta_corriente"
#  [44] "z_mprestamos_personales"
#  [45] "z_mtarjeta_visa_consumo"
#  [46] "z_Visa_mpagominimo"
#  [47] "z_cliente_edad"
#  [48] "z_mpasivos_margen"
#  [49] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z"
#  [50] "ratio_ctrx_quarter_sobre_cpayroll_trx_z"
#  [51] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z"
#  [52] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z"
#  [53] "ratio_ctrx_quarter_sobre_mprestamos_personales_z"
#  [54] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z"
#  [55] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z"
#  [56] "ratio_ctrx_quarter_sobre_cliente_edad_z"
#  [57] "ratio_ctrx_quarter_sobre_mpasivos_margen_z"
#  [58] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z"
#  [59] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z"
#  [60] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z"
#  [61] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z"
#  [62] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z"
#  [63] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z"
#  [64] "ratio_mcaja_ahorro_sobre_cliente_edad_z"
#  [65] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z"
#  [66] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z"
#  [67] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z"
#  [68] "ratio_cpayroll_trx_sobre_mprestamos_personales_z"
#  [69] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z"
#  [70] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z"
#  [71] "ratio_cpayroll_trx_sobre_cliente_edad_z"
#  [72] "ratio_cpayroll_trx_sobre_mpasivos_margen_z"
#  [73] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z"
#  [74] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z"
#  [75] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z"
#  [76] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z"
#  [77] "ratio_mcuentas_saldo_sobre_cliente_edad_z"
#  [78] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z"
#  [79] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z"
#  [80] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z"
#  [81] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z"
#  [82] "ratio_mcuenta_corriente_sobre_cliente_edad_z"
#  [83] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z"
#  [84] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z"
#  [85] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z"
#  [86] "ratio_mprestamos_personales_sobre_cliente_edad_z"
#  [87] "ratio_mprestamos_personales_sobre_mpasivos_margen_z"
#  [88] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z"
#  [89] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z"
#  [90] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z"
#  [91] "ratio_Visa_mpagominimo_sobre_cliente_edad_z"
#  [92] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z"
#  [93] "ratio_cliente_edad_sobre_mpasivos_margen_z"
#  [94] "GA_Feature_1"
#  [95] "GA_Feature_2"
#  [96] "GA_Feature_3"
#  [97] "GA_Feature_4"
#  [98] "GA_Feature_5"
#  [99] "GA_Feature_6"
# [100] "GA_Feature_7"
# [101] "internet_lag1"
# [102] "cliente_edad_lag1"
# [103] "cliente_antiguedad_lag1"
# [104] "mrentabilidad_lag1"
# [105] "mrentabilidad_annual_lag1"
# [106] "mcomisiones_lag1"
# [107] "mactivos_margen_lag1"
# [108] "mpasivos_margen_lag1"
# [109] "cproductos_lag1"
# [110] "mcuenta_corriente_lag1"
# [111] "mcaja_ahorro_lag1"
# [112] "cdescubierto_preacordado_lag1"
# [113] "mcuentas_saldo_lag1"
# [114] "ctarjeta_visa_transacciones_lag1"
# [115] "mtarjeta_visa_consumo_lag1"
# [116] "mtarjeta_master_consumo_lag1"
# [117] "mprestamos_personales_lag1"
# [118] "cpayroll_trx_lag1"
# [119] "mpayroll_lag1"
# [120] "ccomisiones_mantenimiento_lag1"
# [121] "ccallcenter_transacciones_lag1"
# [122] "chomebanking_transacciones_lag1"
# [123] "ctrx_quarter_lag1"
# [124] "Master_status_lag1"
# [125] "Master_fechaalta_lag1"
# [126] "Master_mpagominimo_lag1"
# [127] "Visa_status_lag1"
# [128] "Visa_fechaalta_lag1"
# [129] "Visa_mpagominimo_lag1"
# [130] "kmes_lag1"
# [131] "mpayroll_sobre_edad_lag1"
# [132] "flag_tiene_cpayroll_trx_lag1"
# [133] "flag_tiene_mcuenta_corriente_lag1"
# [134] "flag_tiene_mprestamos_personales_lag1"
# [135] "flag_tiene_Visa_mpagominimo_lag1"
# [136] "z_ctrx_quarter_lag1"
# [137] "z_mcaja_ahorro_lag1"
# [138] "z_cpayroll_trx_lag1"
# [139] "z_mcuentas_saldo_lag1"
# [140] "z_mcuenta_corriente_lag1"
# [141] "z_mprestamos_personales_lag1"
# [142] "z_mtarjeta_visa_consumo_lag1"
# [143] "z_Visa_mpagominimo_lag1"
# [144] "z_cliente_edad_lag1"
# [145] "z_mpasivos_margen_lag1"
# [146] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_lag1"
# [147] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_lag1"
# [148] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_lag1"
# [149] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_lag1"
# [150] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_lag1"
# [151] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_lag1"
# [152] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_lag1"
# [153] "ratio_ctrx_quarter_sobre_cliente_edad_z_lag1"
# [154] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_lag1"
# [155] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_lag1"
# [156] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_lag1"
# [157] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_lag1"
# [158] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_lag1"
# [159] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_lag1"
# [160] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_lag1"
# [161] "ratio_mcaja_ahorro_sobre_cliente_edad_z_lag1"
# [162] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_lag1"
# [163] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_lag1"
# [164] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_lag1"
# [165] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_lag1"
# [166] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_lag1"
# [167] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_lag1"
# [168] "ratio_cpayroll_trx_sobre_cliente_edad_z_lag1"
# [169] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_lag1"
# [170] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_lag1"
# [171] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_lag1"
# [172] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_lag1"
# [173] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_lag1"
# [174] "ratio_mcuentas_saldo_sobre_cliente_edad_z_lag1"
# [175] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_lag1"
# [176] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_lag1"
# [177] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_lag1"
# [178] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_lag1"
# [179] "ratio_mcuenta_corriente_sobre_cliente_edad_z_lag1"
# [180] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_lag1"
# [181] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_lag1"
# [182] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_lag1"
# [183] "ratio_mprestamos_personales_sobre_cliente_edad_z_lag1"
# [184] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_lag1"
# [185] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_lag1"
# [186] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_lag1"
# [187] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_lag1"
# [188] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_lag1"
# [189] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_lag1"
# [190] "ratio_cliente_edad_sobre_mpasivos_margen_z_lag1"
# [191] "GA_Feature_1_lag1"
# [192] "GA_Feature_2_lag1"
# [193] "GA_Feature_3_lag1"
# [194] "GA_Feature_4_lag1"
# [195] "GA_Feature_5_lag1"
# [196] "GA_Feature_6_lag1"
# [197] "GA_Feature_7_lag1"
# [198] "internet_lag2"
# [199] "cliente_edad_lag2"
# [200] "cliente_antiguedad_lag2"
# [201] "mrentabilidad_lag2"
# [202] "mrentabilidad_annual_lag2"
# [203] "mcomisiones_lag2"
# [204] "mactivos_margen_lag2"
# [205] "mpasivos_margen_lag2"
# [206] "cproductos_lag2"
# [207] "mcuenta_corriente_lag2"
# [208] "mcaja_ahorro_lag2"
# [209] "cdescubierto_preacordado_lag2"
# [210] "mcuentas_saldo_lag2"
# [211] "ctarjeta_visa_transacciones_lag2"
# [212] "mtarjeta_visa_consumo_lag2"
# [213] "mtarjeta_master_consumo_lag2"
# [214] "mprestamos_personales_lag2"
# [215] "cpayroll_trx_lag2"
# [216] "mpayroll_lag2"
# [217] "ccomisiones_mantenimiento_lag2"
# [218] "ccallcenter_transacciones_lag2"
# [219] "chomebanking_transacciones_lag2"
# [220] "ctrx_quarter_lag2"
# [221] "Master_status_lag2"
# [222] "Master_fechaalta_lag2"
# [223] "Master_mpagominimo_lag2"
# [224] "Visa_status_lag2"
# [225] "Visa_fechaalta_lag2"
# [226] "Visa_mpagominimo_lag2"
# [227] "kmes_lag2"
# [228] "mpayroll_sobre_edad_lag2"
# [229] "flag_tiene_cpayroll_trx_lag2"
# [230] "flag_tiene_mcuenta_corriente_lag2"
# [231] "flag_tiene_mprestamos_personales_lag2"
# [232] "flag_tiene_Visa_mpagominimo_lag2"
# [233] "z_ctrx_quarter_lag2"
# [234] "z_mcaja_ahorro_lag2"
# [235] "z_cpayroll_trx_lag2"
# [236] "z_mcuentas_saldo_lag2"
# [237] "z_mcuenta_corriente_lag2"
# [238] "z_mprestamos_personales_lag2"
# [239] "z_mtarjeta_visa_consumo_lag2"
# [240] "z_Visa_mpagominimo_lag2"
# [241] "z_cliente_edad_lag2"
# [242] "z_mpasivos_margen_lag2"
# [243] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_lag2"
# [244] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_lag2"
# [245] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_lag2"
# [246] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_lag2"
# [247] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_lag2"
# [248] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_lag2"
# [249] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_lag2"
# [250] "ratio_ctrx_quarter_sobre_cliente_edad_z_lag2"
# [251] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_lag2"
# [252] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_lag2"
# [253] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_lag2"
# [254] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_lag2"
# [255] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_lag2"
# [256] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_lag2"
# [257] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_lag2"
# [258] "ratio_mcaja_ahorro_sobre_cliente_edad_z_lag2"
# [259] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_lag2"
# [260] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_lag2"
# [261] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_lag2"
# [262] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_lag2"
# [263] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_lag2"
# [264] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_lag2"
# [265] "ratio_cpayroll_trx_sobre_cliente_edad_z_lag2"
# [266] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_lag2"
# [267] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_lag2"
# [268] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_lag2"
# [269] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_lag2"
# [270] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_lag2"
# [271] "ratio_mcuentas_saldo_sobre_cliente_edad_z_lag2"
# [272] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_lag2"
# [273] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_lag2"
# [274] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_lag2"
# [275] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_lag2"
# [276] "ratio_mcuenta_corriente_sobre_cliente_edad_z_lag2"
# [277] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_lag2"
# [278] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_lag2"
# [279] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_lag2"
# [280] "ratio_mprestamos_personales_sobre_cliente_edad_z_lag2"
# [281] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_lag2"
# [282] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_lag2"
# [283] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_lag2"
# [284] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_lag2"
# [285] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_lag2"
# [286] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_lag2"
# [287] "ratio_cliente_edad_sobre_mpasivos_margen_z_lag2"
# [288] "GA_Feature_1_lag2"
# [289] "GA_Feature_2_lag2"
# [290] "GA_Feature_3_lag2"
# [291] "GA_Feature_4_lag2"
# [292] "GA_Feature_5_lag2"
# [293] "GA_Feature_6_lag2"
# [294] "GA_Feature_7_lag2"
# [295] "internet_lag3"
# [296] "cliente_edad_lag3"
# [297] "cliente_antiguedad_lag3"
# [298] "mrentabilidad_lag3"
# [299] "mrentabilidad_annual_lag3"
# [300] "mcomisiones_lag3"
# [301] "mactivos_margen_lag3"
# [302] "mpasivos_margen_lag3"
# [303] "cproductos_lag3"
# [304] "mcuenta_corriente_lag3"
# [305] "mcaja_ahorro_lag3"
# [306] "cdescubierto_preacordado_lag3"
# [307] "mcuentas_saldo_lag3"
# [308] "ctarjeta_visa_transacciones_lag3"
# [309] "mtarjeta_visa_consumo_lag3"
# [310] "mtarjeta_master_consumo_lag3"
# [311] "mprestamos_personales_lag3"
# [312] "cpayroll_trx_lag3"
# [313] "mpayroll_lag3"
# [314] "ccomisiones_mantenimiento_lag3"
# [315] "ccallcenter_transacciones_lag3"
# [316] "chomebanking_transacciones_lag3"
# [317] "ctrx_quarter_lag3"
# [318] "Master_status_lag3"
# [319] "Master_fechaalta_lag3"
# [320] "Master_mpagominimo_lag3"
# [321] "Visa_status_lag3"
# [322] "Visa_fechaalta_lag3"
# [323] "Visa_mpagominimo_lag3"
# [324] "kmes_lag3"
# [325] "mpayroll_sobre_edad_lag3"
# [326] "flag_tiene_cpayroll_trx_lag3"
# [327] "flag_tiene_mcuenta_corriente_lag3"
# [328] "flag_tiene_mprestamos_personales_lag3"
# [329] "flag_tiene_Visa_mpagominimo_lag3"
# [330] "z_ctrx_quarter_lag3"
# [331] "z_mcaja_ahorro_lag3"
# [332] "z_cpayroll_trx_lag3"
# [333] "z_mcuentas_saldo_lag3"
# [334] "z_mcuenta_corriente_lag3"
# [335] "z_mprestamos_personales_lag3"
# [336] "z_mtarjeta_visa_consumo_lag3"
# [337] "z_Visa_mpagominimo_lag3"
# [338] "z_cliente_edad_lag3"
# [339] "z_mpasivos_margen_lag3"
# [340] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_lag3"
# [341] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_lag3"
# [342] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_lag3"
# [343] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_lag3"
# [344] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_lag3"
# [345] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_lag3"
# [346] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_lag3"
# [347] "ratio_ctrx_quarter_sobre_cliente_edad_z_lag3"
# [348] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_lag3"
# [349] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_lag3"
# [350] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_lag3"
# [351] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_lag3"
# [352] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_lag3"
# [353] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_lag3"
# [354] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_lag3"
# [355] "ratio_mcaja_ahorro_sobre_cliente_edad_z_lag3"
# [356] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_lag3"
# [357] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_lag3"
# [358] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_lag3"
# [359] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_lag3"
# [360] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_lag3"
# [361] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_lag3"
# [362] "ratio_cpayroll_trx_sobre_cliente_edad_z_lag3"
# [363] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_lag3"
# [364] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_lag3"
# [365] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_lag3"
# [366] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_lag3"
# [367] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_lag3"
# [368] "ratio_mcuentas_saldo_sobre_cliente_edad_z_lag3"
# [369] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_lag3"
# [370] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_lag3"
# [371] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_lag3"
# [372] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_lag3"
# [373] "ratio_mcuenta_corriente_sobre_cliente_edad_z_lag3"
# [374] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_lag3"
# [375] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_lag3"
# [376] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_lag3"
# [377] "ratio_mprestamos_personales_sobre_cliente_edad_z_lag3"
# [378] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_lag3"
# [379] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_lag3"
# [380] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_lag3"
# [381] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_lag3"
# [382] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_lag3"
# [383] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_lag3"
# [384] "ratio_cliente_edad_sobre_mpasivos_margen_z_lag3"
# [385] "GA_Feature_1_lag3"
# [386] "GA_Feature_2_lag3"
# [387] "GA_Feature_3_lag3"
# [388] "GA_Feature_4_lag3"
# [389] "GA_Feature_5_lag3"
# [390] "GA_Feature_6_lag3"
# [391] "GA_Feature_7_lag3"
# [392] "internet_delta1"
# [393] "internet_delta2"
# [394] "internet_delta3"
# [395] "cliente_edad_delta1"
# [396] "cliente_edad_delta2"
# [397] "cliente_edad_delta3"
# [398] "cliente_antiguedad_delta1"
# [399] "cliente_antiguedad_delta2"
# [400] "cliente_antiguedad_delta3"
# [401] "mrentabilidad_delta1"
# [402] "mrentabilidad_delta2"
# [403] "mrentabilidad_delta3"
# [404] "mrentabilidad_annual_delta1"
# [405] "mrentabilidad_annual_delta2"
# [406] "mrentabilidad_annual_delta3"
# [407] "mcomisiones_delta1"
# [408] "mcomisiones_delta2"
# [409] "mcomisiones_delta3"
# [410] "mactivos_margen_delta1"
# [411] "mactivos_margen_delta2"
# [412] "mactivos_margen_delta3"
# [413] "mpasivos_margen_delta1"
# [414] "mpasivos_margen_delta2"
# [415] "mpasivos_margen_delta3"
# [416] "cproductos_delta1"
# [417] "cproductos_delta2"
# [418] "cproductos_delta3"
# [419] "mcuenta_corriente_delta1"
# [420] "mcuenta_corriente_delta2"
# [421] "mcuenta_corriente_delta3"
# [422] "mcaja_ahorro_delta1"
# [423] "mcaja_ahorro_delta2"
# [424] "mcaja_ahorro_delta3"
# [425] "cdescubierto_preacordado_delta1"
# [426] "cdescubierto_preacordado_delta2"
# [427] "cdescubierto_preacordado_delta3"
# [428] "mcuentas_saldo_delta1"
# [429] "mcuentas_saldo_delta2"
# [430] "mcuentas_saldo_delta3"
# [431] "ctarjeta_visa_transacciones_delta1"
# [432] "ctarjeta_visa_transacciones_delta2"
# [433] "ctarjeta_visa_transacciones_delta3"
# [434] "mtarjeta_visa_consumo_delta1"
# [435] "mtarjeta_visa_consumo_delta2"
# [436] "mtarjeta_visa_consumo_delta3"
# [437] "mtarjeta_master_consumo_delta1"
# [438] "mtarjeta_master_consumo_delta2"
# [439] "mtarjeta_master_consumo_delta3"
# [440] "mprestamos_personales_delta1"
# [441] "mprestamos_personales_delta2"
# [442] "mprestamos_personales_delta3"
# [443] "cpayroll_trx_delta1"
# [444] "cpayroll_trx_delta2"
# [445] "cpayroll_trx_delta3"
# [446] "mpayroll_delta1"
# [447] "mpayroll_delta2"
# [448] "mpayroll_delta3"
# [449] "ccomisiones_mantenimiento_delta1"
# [450] "ccomisiones_mantenimiento_delta2"
# [451] "ccomisiones_mantenimiento_delta3"
# [452] "ccallcenter_transacciones_delta1"
# [453] "ccallcenter_transacciones_delta2"
# [454] "ccallcenter_transacciones_delta3"
# [455] "chomebanking_transacciones_delta1"
# [456] "chomebanking_transacciones_delta2"
# [457] "chomebanking_transacciones_delta3"
# [458] "ctrx_quarter_delta1"
# [459] "ctrx_quarter_delta2"
# [460] "ctrx_quarter_delta3"
# [461] "Master_status_delta1"
# [462] "Master_status_delta2"
# [463] "Master_status_delta3"
# [464] "Master_fechaalta_delta1"
# [465] "Master_fechaalta_delta2"
# [466] "Master_fechaalta_delta3"
# [467] "Master_mpagominimo_delta1"
# [468] "Master_mpagominimo_delta2"
# [469] "Master_mpagominimo_delta3"
# [470] "Visa_status_delta1"
# [471] "Visa_status_delta2"
# [472] "Visa_status_delta3"
# [473] "Visa_fechaalta_delta1"
# [474] "Visa_fechaalta_delta2"
# [475] "Visa_fechaalta_delta3"
# [476] "Visa_mpagominimo_delta1"
# [477] "Visa_mpagominimo_delta2"
# [478] "Visa_mpagominimo_delta3"
# [479] "kmes_delta1"
# [480] "kmes_delta2"
# [481] "kmes_delta3"
# [482] "mpayroll_sobre_edad_delta1"
# [483] "mpayroll_sobre_edad_delta2"
# [484] "mpayroll_sobre_edad_delta3"
# [485] "flag_tiene_cpayroll_trx_delta1"
# [486] "flag_tiene_cpayroll_trx_delta2"
# [487] "flag_tiene_cpayroll_trx_delta3"
# [488] "flag_tiene_mcuenta_corriente_delta1"
# [489] "flag_tiene_mcuenta_corriente_delta2"
# [490] "flag_tiene_mcuenta_corriente_delta3"
# [491] "flag_tiene_mprestamos_personales_delta1"
# [492] "flag_tiene_mprestamos_personales_delta2"
# [493] "flag_tiene_mprestamos_personales_delta3"
# [494] "flag_tiene_Visa_mpagominimo_delta1"
# [495] "flag_tiene_Visa_mpagominimo_delta2"
# [496] "flag_tiene_Visa_mpagominimo_delta3"
# [497] "z_ctrx_quarter_delta1"
# [498] "z_ctrx_quarter_delta2"
# [499] "z_ctrx_quarter_delta3"
# [500] "z_mcaja_ahorro_delta1"
# [501] "z_mcaja_ahorro_delta2"
# [502] "z_mcaja_ahorro_delta3"
# [503] "z_cpayroll_trx_delta1"
# [504] "z_cpayroll_trx_delta2"
# [505] "z_cpayroll_trx_delta3"
# [506] "z_mcuentas_saldo_delta1"
# [507] "z_mcuentas_saldo_delta2"
# [508] "z_mcuentas_saldo_delta3"
# [509] "z_mcuenta_corriente_delta1"
# [510] "z_mcuenta_corriente_delta2"
# [511] "z_mcuenta_corriente_delta3"
# [512] "z_mprestamos_personales_delta1"
# [513] "z_mprestamos_personales_delta2"
# [514] "z_mprestamos_personales_delta3"
# [515] "z_mtarjeta_visa_consumo_delta1"
# [516] "z_mtarjeta_visa_consumo_delta2"
# [517] "z_mtarjeta_visa_consumo_delta3"
# [518] "z_Visa_mpagominimo_delta1"
# [519] "z_Visa_mpagominimo_delta2"
# [520] "z_Visa_mpagominimo_delta3"
# [521] "z_cliente_edad_delta1"
# [522] "z_cliente_edad_delta2"
# [523] "z_cliente_edad_delta3"
# [524] "z_mpasivos_margen_delta1"
# [525] "z_mpasivos_margen_delta2"
# [526] "z_mpasivos_margen_delta3"
# [527] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_delta1"
# [528] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_delta2"
# [529] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_delta3"
# [530] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_delta1"
# [531] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_delta2"
# [532] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_delta3"
# [533] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_delta1"
# [534] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_delta2"
# [535] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_delta3"
# [536] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_delta1"
# [537] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_delta2"
# [538] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_delta3"
# [539] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_delta1"
# [540] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_delta2"
# [541] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_delta3"
# [542] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_delta1"
# [543] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_delta2"
# [544] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_delta3"
# [545] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_delta1"
# [546] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_delta2"
# [547] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_delta3"
# [548] "ratio_ctrx_quarter_sobre_cliente_edad_z_delta1"
# [549] "ratio_ctrx_quarter_sobre_cliente_edad_z_delta2"
# [550] "ratio_ctrx_quarter_sobre_cliente_edad_z_delta3"
# [551] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_delta1"
# [552] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_delta2"
# [553] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_delta3"
# [554] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_delta1"
# [555] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_delta2"
# [556] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_delta3"
# [557] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_delta1"
# [558] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_delta2"
# [559] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_delta3"
# [560] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_delta1"
# [561] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_delta2"
# [562] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_delta3"
# [563] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_delta1"
# [564] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_delta2"
# [565] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_delta3"
# [566] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_delta1"
# [567] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_delta2"
# [568] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_delta3"
# [569] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_delta1"
# [570] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_delta2"
# [571] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_delta3"
# [572] "ratio_mcaja_ahorro_sobre_cliente_edad_z_delta1"
# [573] "ratio_mcaja_ahorro_sobre_cliente_edad_z_delta2"
# [574] "ratio_mcaja_ahorro_sobre_cliente_edad_z_delta3"
# [575] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_delta1"
# [576] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_delta2"
# [577] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_delta3"
# [578] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_delta1"
# [579] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_delta2"
# [580] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_delta3"
# [581] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_delta1"
# [582] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_delta2"
# [583] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_delta3"
# [584] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_delta1"
# [585] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_delta2"
# [586] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_delta3"
# [587] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_delta1"
# [588] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_delta2"
# [589] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_delta3"
# [590] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_delta1"
# [591] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_delta2"
# [592] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_delta3"
# [593] "ratio_cpayroll_trx_sobre_cliente_edad_z_delta1"
# [594] "ratio_cpayroll_trx_sobre_cliente_edad_z_delta2"
# [595] "ratio_cpayroll_trx_sobre_cliente_edad_z_delta3"
# [596] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_delta1"
# [597] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_delta2"
# [598] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_delta3"
# [599] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_delta1"
# [600] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_delta2"
# [601] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_delta3"
# [602] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_delta1"
# [603] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_delta2"
# [604] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_delta3"
# [605] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_delta1"
# [606] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_delta2"
# [607] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_delta3"
# [608] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_delta1"
# [609] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_delta2"
# [610] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_delta3"
# [611] "ratio_mcuentas_saldo_sobre_cliente_edad_z_delta1"
# [612] "ratio_mcuentas_saldo_sobre_cliente_edad_z_delta2"
# [613] "ratio_mcuentas_saldo_sobre_cliente_edad_z_delta3"
# [614] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_delta1"
# [615] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_delta2"
# [616] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_delta3"
# [617] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_delta1"
# [618] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_delta2"
# [619] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_delta3"
# [620] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_delta1"
# [621] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_delta2"
# [622] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_delta3"
# [623] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_delta1"
# [624] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_delta2"
# [625] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_delta3"
# [626] "ratio_mcuenta_corriente_sobre_cliente_edad_z_delta1"
# [627] "ratio_mcuenta_corriente_sobre_cliente_edad_z_delta2"
# [628] "ratio_mcuenta_corriente_sobre_cliente_edad_z_delta3"
# [629] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_delta1"
# [630] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_delta2"
# [631] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_delta3"
# [632] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_delta1"
# [633] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_delta2"
# [634] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_delta3"
# [635] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_delta1"
# [636] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_delta2"
# [637] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_delta3"
# [638] "ratio_mprestamos_personales_sobre_cliente_edad_z_delta1"
# [639] "ratio_mprestamos_personales_sobre_cliente_edad_z_delta2"
# [640] "ratio_mprestamos_personales_sobre_cliente_edad_z_delta3"
# [641] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_delta1"
# [642] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_delta2"
# [643] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_delta3"
# [644] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_delta1"
# [645] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_delta2"
# [646] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_delta3"
# [647] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_delta1"
# [648] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_delta2"
# [649] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_delta3"
# [650] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_delta1"
# [651] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_delta2"
# [652] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_delta3"
# [653] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_delta1"
# [654] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_delta2"
# [655] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_delta3"
# [656] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_delta1"
# [657] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_delta2"
# [658] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_delta3"
# [659] "ratio_cliente_edad_sobre_mpasivos_margen_z_delta1"
# [660] "ratio_cliente_edad_sobre_mpasivos_margen_z_delta2"
# [661] "ratio_cliente_edad_sobre_mpasivos_margen_z_delta3"
# [662] "GA_Feature_1_delta1"
# [663] "GA_Feature_1_delta2"
# [664] "GA_Feature_1_delta3"
# [665] "GA_Feature_2_delta1"
# [666] "GA_Feature_2_delta2"
# [667] "GA_Feature_2_delta3"
# [668] "GA_Feature_3_delta1"
# [669] "GA_Feature_3_delta2"
# [670] "GA_Feature_3_delta3"
# [671] "GA_Feature_4_delta1"
# [672] "GA_Feature_4_delta2"
# [673] "GA_Feature_4_delta3"
# [674] "GA_Feature_5_delta1"
# [675] "GA_Feature_5_delta2"
# [676] "GA_Feature_5_delta3"
# [677] "GA_Feature_6_delta1"
# [678] "GA_Feature_6_delta2"
# [679] "GA_Feature_6_delta3"
# [680] "GA_Feature_7_delta1"
# [681] "GA_Feature_7_delta2"
# [682] "GA_Feature_7_delta3"
# [683] "internet_ma3"
# [684] "cliente_edad_ma3"
# [685] "cliente_antiguedad_ma3"
# [686] "mrentabilidad_ma3"
# [687] "mrentabilidad_annual_ma3"
# [688] "mcomisiones_ma3"
# [689] "mactivos_margen_ma3"
# [690] "mpasivos_margen_ma3"
# [691] "cproductos_ma3"
# [692] "mcuenta_corriente_ma3"
# [693] "mcaja_ahorro_ma3"
# [694] "cdescubierto_preacordado_ma3"
# [695] "mcuentas_saldo_ma3"
# [696] "ctarjeta_visa_transacciones_ma3"
# [697] "mtarjeta_visa_consumo_ma3"
# [698] "mtarjeta_master_consumo_ma3"
# [699] "mprestamos_personales_ma3"
# [700] "cpayroll_trx_ma3"
# [701] "mpayroll_ma3"
# [702] "ccomisiones_mantenimiento_ma3"
# [703] "ccallcenter_transacciones_ma3"
# [704] "chomebanking_transacciones_ma3"
# [705] "ctrx_quarter_ma3"
# [706] "Master_status_ma3"
# [707] "Master_fechaalta_ma3"
# [708] "Master_mpagominimo_ma3"
# [709] "Visa_status_ma3"
# [710] "Visa_fechaalta_ma3"
# [711] "Visa_mpagominimo_ma3"
# [712] "kmes_ma3"
# [713] "mpayroll_sobre_edad_ma3"
# [714] "flag_tiene_cpayroll_trx_ma3"
# [715] "flag_tiene_mcuenta_corriente_ma3"
# [716] "flag_tiene_mprestamos_personales_ma3"
# [717] "flag_tiene_Visa_mpagominimo_ma3"
# [718] "z_ctrx_quarter_ma3"
# [719] "z_mcaja_ahorro_ma3"
# [720] "z_cpayroll_trx_ma3"
# [721] "z_mcuentas_saldo_ma3"
# [722] "z_mcuenta_corriente_ma3"
# [723] "z_mprestamos_personales_ma3"
# [724] "z_mtarjeta_visa_consumo_ma3"
# [725] "z_Visa_mpagominimo_ma3"
# [726] "z_cliente_edad_ma3"
# [727] "z_mpasivos_margen_ma3"
# [728] "ratio_ctrx_quarter_sobre_mcaja_ahorro_z_ma3"
# [729] "ratio_ctrx_quarter_sobre_cpayroll_trx_z_ma3"
# [730] "ratio_ctrx_quarter_sobre_mcuentas_saldo_z_ma3"
# [731] "ratio_ctrx_quarter_sobre_mcuenta_corriente_z_ma3"
# [732] "ratio_ctrx_quarter_sobre_mprestamos_personales_z_ma3"
# [733] "ratio_ctrx_quarter_sobre_mtarjeta_visa_consumo_z_ma3"
# [734] "ratio_ctrx_quarter_sobre_Visa_mpagominimo_z_ma3"
# [735] "ratio_ctrx_quarter_sobre_cliente_edad_z_ma3"
# [736] "ratio_ctrx_quarter_sobre_mpasivos_margen_z_ma3"
# [737] "ratio_mcaja_ahorro_sobre_cpayroll_trx_z_ma3"
# [738] "ratio_mcaja_ahorro_sobre_mcuentas_saldo_z_ma3"
# [739] "ratio_mcaja_ahorro_sobre_mcuenta_corriente_z_ma3"
# [740] "ratio_mcaja_ahorro_sobre_mprestamos_personales_z_ma3"
# [741] "ratio_mcaja_ahorro_sobre_mtarjeta_visa_consumo_z_ma3"
# [742] "ratio_mcaja_ahorro_sobre_Visa_mpagominimo_z_ma3"
# [743] "ratio_mcaja_ahorro_sobre_cliente_edad_z_ma3"
# [744] "ratio_mcaja_ahorro_sobre_mpasivos_margen_z_ma3"
# [745] "ratio_cpayroll_trx_sobre_mcuentas_saldo_z_ma3"
# [746] "ratio_cpayroll_trx_sobre_mcuenta_corriente_z_ma3"
# [747] "ratio_cpayroll_trx_sobre_mprestamos_personales_z_ma3"
# [748] "ratio_cpayroll_trx_sobre_mtarjeta_visa_consumo_z_ma3"
# [749] "ratio_cpayroll_trx_sobre_Visa_mpagominimo_z_ma3"
# [750] "ratio_cpayroll_trx_sobre_cliente_edad_z_ma3"
# [751] "ratio_cpayroll_trx_sobre_mpasivos_margen_z_ma3"
# [752] "ratio_mcuentas_saldo_sobre_mcuenta_corriente_z_ma3"
# [753] "ratio_mcuentas_saldo_sobre_mprestamos_personales_z_ma3"
# [754] "ratio_mcuentas_saldo_sobre_mtarjeta_visa_consumo_z_ma3"
# [755] "ratio_mcuentas_saldo_sobre_Visa_mpagominimo_z_ma3"
# [756] "ratio_mcuentas_saldo_sobre_cliente_edad_z_ma3"
# [757] "ratio_mcuentas_saldo_sobre_mpasivos_margen_z_ma3"
# [758] "ratio_mcuenta_corriente_sobre_mprestamos_personales_z_ma3"
# [759] "ratio_mcuenta_corriente_sobre_mtarjeta_visa_consumo_z_ma3"
# [760] "ratio_mcuenta_corriente_sobre_Visa_mpagominimo_z_ma3"
# [761] "ratio_mcuenta_corriente_sobre_cliente_edad_z_ma3"
# [762] "ratio_mcuenta_corriente_sobre_mpasivos_margen_z_ma3"
# [763] "ratio_mprestamos_personales_sobre_mtarjeta_visa_consumo_z_ma3"
# [764] "ratio_mprestamos_personales_sobre_Visa_mpagominimo_z_ma3"
# [765] "ratio_mprestamos_personales_sobre_cliente_edad_z_ma3"
# [766] "ratio_mprestamos_personales_sobre_mpasivos_margen_z_ma3"
# [767] "ratio_mtarjeta_visa_consumo_sobre_Visa_mpagominimo_z_ma3"
# [768] "ratio_mtarjeta_visa_consumo_sobre_cliente_edad_z_ma3"
# [769] "ratio_mtarjeta_visa_consumo_sobre_mpasivos_margen_z_ma3"
# [770] "ratio_Visa_mpagominimo_sobre_cliente_edad_z_ma3"
# [771] "ratio_Visa_mpagominimo_sobre_mpasivos_margen_z_ma3"
# [772] "ratio_cliente_edad_sobre_mpasivos_margen_z_ma3"
# [773] "GA_Feature_1_ma3"
# [774] "GA_Feature_2_ma3"
# [775] "GA_Feature_3_ma3"
# [776] "GA_Feature_4_ma3"
# [777] "GA_Feature_5_ma3"
# [778] "GA_Feature_6_ma3"
# [779] "GA_Feature_7_ma3"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset reducido de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

# Problema #12 - Grupo A (Víctor y David)
# Usamos 100% de CONTINUA durante el Grid Search
PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %% [markdown]
# En el notebook original esta etapa incluye la instalación de LightGBM y se advierte una demora importante en Colab.
# <br>En Cloud/Jupyter el tiempo dependerá de si `lightgbm` ya está instalado en la VM y de los recursos asignados.

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 13202

# %%
# ================================================================
# CONTROL 3 - TRAINING / UNDERSAMPLING
# Comprueba que entren todos los positivos y que el undersampling
# afecte únicamente a CONTINUA.
# ================================================================

control_training <- dataset[
  foto_mes %in% PARAM$trainingstrategy$training,
  .(
    filas_training = .N,
    positivos_total = sum(clase01 == 1L, na.rm = TRUE),
    positivos_usados = sum(fold_train & clase01 == 1L, na.rm = TRUE),
    continua_total = sum(clase01 == 0L, na.rm = TRUE),
    continua_usados = sum(fold_train & clase01 == 0L, na.rm = TRUE)
  )
]

control_training[
  , pct_continua_real := continua_usados / continua_total
]

print(control_training)

if (control_training$positivos_usados != control_training$positivos_total)
  stop("CONTROL Training: no están entrando todos los positivos.")

if (control_training$continua_usados <= 0)
  stop("CONTROL Training: no entró ningún CONTINUA.")

cat(
  "CONTROL Training OK | training_pct configurado:",
  PARAM$trainingstrategy$training_pct,
  "| proporción real CONTINUA:",
  round(control_training$pct_continua_real, 4), "\n"
)
# Out:
#    filas_training positivos_total positivos_usados continua_total
#             <int>           <int>            <int>          <int>
# 1:         179449            1673             1673         177776
#    continua_usados pct_continua_real
#              <int>             <num>
# 1:          177776                 1
# CONTROL Training OK | training_pct configurado: 1 | proporción real CONTINUA: 1

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.50  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en el Grid Search
#   * num_leaves  [64, 512]
#   * min_data_in_leaf  [64, 2048]

# %%
# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  learning_rate= 0.03,
  feature_fraction= 0.50,
  num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 200,
  num_leaves= 64,
  min_data_in_leaf= 128
)

# %%
# En  x llegan los parametros moviles de LightGBM
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

Estimar_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  message(format(Sys.time(), "%a %b %d %X %Y  "),
    toString(x),
    " niter ", modelo_train$best_iter,
    " AUC ", AUC
  )

  niter <- modelo_train$best_iter
  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  return( list(AUC, niter))
}

# %% [markdown]
# seteo del Grid Search

# %%
# lo que sigue a continuacion es una forma alternativa a los loops anidados
# creo una tabla con el producto cartesiano de los vectores
tb_nueva <- CJ(
  num_leaves= c(64, 128, 256, 512),
  min_data_in_leaf= c(64, 256, 512, 1024, 2048)
)

# %% [markdown]
# Corrida del Grid Search: aquí se hace el trabajo pesado.
# <br>El notebook original advierte aproximadamente 50 minutos en Colab.
# <br>En la VM Cloud conviene registrar el tiempo real de cada corrida porque dependerá de los recursos de la máquina.

# %%
# registro a registro calculo la AUC
tb_nueva[, c("AUC", "num_iterations"):= Estimar_AUC_lightgbm( .SD ),
  by=1:nrow(tb_nueva) ]
# Out:
# Sat Sep 19 16:48:50 2026  64, 64 niter 305 AUC 0.947712027066593
#
# Sat Sep 19 16:49:33 2026  64, 256 niter 182 AUC 0.947231421538328
#
# Sat Sep 19 16:50:14 2026  64, 512 niter 110 AUC 0.948849344480952
#
# Sat Sep 19 16:51:37 2026  64, 1024 niter 483 AUC 0.950881073988527
#
# Sat Sep 19 16:53:00 2026  64, 2048 niter 423 AUC 0.951391608922433
#
# Sat Sep 19 16:54:39 2026  128, 64 niter 460 AUC 0.950659422882983
#
# Sat Sep 19 16:56:22 2026  128, 256 niter 472 AUC 0.952461693613976
#
# Sat Sep 19 16:57:24 2026  128, 512 niter 197 AUC 0.952509840918703
#
# Sat Sep 19 16:59:11 2026  128, 1024 niter 462 AUC 0.95141633321405
#
# Sat Sep 19 17:00:28 2026  128, 2048 niter 348 AUC 0.949556806228786
#
# Sat Sep 19 17:02:46 2026  256, 64 niter 479 AUC 0.952155893165035
#
# Sat Sep 19 17:05:29 2026  256, 256 niter 581 AUC 0.953736946549985
#
# Sat Sep 19 17:07:35 2026  256, 512 niter 373 AUC 0.952266935597558
#
# Sat Sep 19 17:09:11 2026  256, 1024 niter 339 AUC 0.951773317284232
#
# Sat Sep 19 17:10:23 2026  256, 2048 niter 348 AUC 0.949556806228786
#
# Sat Sep 19 17:12:59 2026  512, 64 niter 423 AUC 0.954735460923691
#
# Sat Sep 19 17:15:45 2026  512, 256 niter 396 AUC 0.95301647201709
#
# Sat Sep 19 17:17:58 2026  512, 512 niter 343 AUC 0.95130182070551
#
# Sat Sep 19 17:19:35 2026  512, 1024 niter 339 AUC 0.951773317284232
#
# Sat Sep 19 17:20:47 2026  512, 2048 niter 348 AUC 0.949556806228786

# %% [markdown]
# la optimizacion de hiperparámetros de tipo  Grid Search ha corrido, extraigo los mejores hiperparametros

# %%
tb_nueva

fwrite( tb_nueva,
  file= "tb_grid_search_01.txt",
  sep="\t",
  append= TRUE
)
# Out:
#    num_leaves min_data_in_leaf AUC       num_iterations
# 1   64          64             0.9477120 305
# 2   64         256             0.9472314 182
# 3   64         512             0.9488493 110
# 4   64        1024             0.9508811 483
# 5   64        2048             0.9513916 423
# 6  128          64             0.9506594 460
# 7  128         256             0.9524617 472
# 8  128         512             0.9525098 197
# 9  128        1024             0.9514163 462
# 10 128        2048             0.9495568 348
# 11 256          64             0.9521559 479
# 12 256         256             0.9537369 581
# 13 256         512             0.9522669 373
# 14 256        1024             0.9517733 339
# 15 256        2048             0.9495568 348
# 16 512          64             0.9547355 423
# 17 512         256             0.9530165 396
# 18 512         512             0.9513018 343
# 19 512        1024             0.9517733 339
# 20 512        2048             0.9495568 348

# %%
setorder( tb_nueva, -AUC)  # ordeno DESCENDENTE por AUC
PARAM$out$lgbm$AUC <- tb_nueva[1, AUC] # en la posicion 1 estan los mejores
PARAM$out$lgbm$mejores_hiperparametros <- as.list( tb_nueva[1] )
PARAM$out$lgbm$mejores_hiperparametros$AUC <- NULL
PARAM$out$lgbm$mejores_hiperparametros
# Out:
# $num_leaves
# [1] 512
#
# $min_data_in_leaf
# [1] 64
#
# $num_iterations
# [1] 423

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en optimización de hiperparámetros

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 192651

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los mejores encontrados por el Grid Search
# FIX heredado de 7192: modifyList reemplaza correctamente los valores fijos
# por los hiperparametros ganadores del Grid Search.
param_final <- modifyList(
  fijos,
  PARAM$out$lgbm$mejores_hiperparametros
)

# %%
# ================================================================
# CONTROL 4 - PARAM_FINAL
#
# Verifica que los hiperparametros elegidos por el Grid Search
# hayan reemplazado realmente a los valores fijos.
# ================================================================

mejores <- PARAM$out$lgbm$mejores_hiperparametros

# No deberían existir nombres duplicados al usar modifyList()
nombres_duplicados <- unique(names(param_final)[duplicated(names(param_final))])

if (length(nombres_duplicados) > 0) {
  stop(
    "CONTROL param_final [", PARAM$experimento,
    "]: todavía hay nombres duplicados: ",
    paste(nombres_duplicados, collapse = ", ")
  )
}

# Verifico uno por uno los hiperparametros elegidos por el Grid Search
for (nm in names(mejores)) {

  valor_final <- param_final[[nm]]
  valor_grid  <- mejores[[nm]]

  if (!isTRUE(all.equal(valor_final, valor_grid))) {
    stop(
      "CONTROL param_final [", PARAM$experimento, "]: ",
      nm,
      " no coincide. Grid Search=",
      valor_grid,
      " | param_final=",
      valor_final
    )
  }
}

cat(
  "CONTROL param_final [", PARAM$experimento, "] OK | ",
  "num_leaves:", param_final$num_leaves,
  "| min_data_in_leaf:", param_final$min_data_in_leaf,
  "| num_iterations:", param_final$num_iterations,
  "
"
)
# Out:
# CONTROL param_final [ 719_LGBM01 ] OK |  num_leaves: 512 | min_data_in_leaf: 64 | num_iterations: 423

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# ### PASO 2 — Generar CSV y enviarlos automáticamente a Kaggle
#
# Esta corrida está configurada con:
#
# ```r
# PARAM$control$submit_kaggle <- TRUE
# ```
#
# Al hacer **Run All**, el PASO 2:
#
# - controla las predicciones;
# - genera los 11 CSV (`800, 850, ..., 1300`);
# - verifica nuevamente el acceso a Kaggle;
# - envía automáticamente los 11 submissions;
# - si un envío falla, detiene el proceso para no continuar enviando.
#
# No hace falta volver a ejecutar FE, GA, FE histórico, Grid Search ni Final Training.

# %%
# ================================================================
# PASO 2 - KAGGLE
#
# MODO AUTOMATICO DE ESTA CORRIDA:
#   TRUE = genera los 11 CSV y los envía a Kaggle.
#   Si un submit falla, el proceso se detiene.
# ================================================================

PARAM$control$submit_kaggle <- TRUE

PARAM$kaggle$competencia <- "utn-2026-virtual-mgr"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ------------------------------------------------
# A) Controles previos de las predicciones
# ------------------------------------------------
if (!exists("tb_prediccion"))
  stop("CONTROL Kaggle: no existe tb_prediccion.")

if (nrow(tb_prediccion) < max(PARAM$kaggle$cortes))
  stop("CONTROL Kaggle: hay menos filas que el corte máximo.")

if (anyDuplicated(tb_prediccion$numero_de_cliente) > 0)
  stop("CONTROL Kaggle: hay numero_de_cliente duplicados.")

if (any(!is.finite(tb_prediccion$prob)))
  stop("CONTROL Kaggle: hay probabilidades NA/Inf/NaN.")

cat(
  "CONTROL PRE-KAGGLE OK | clientes:", nrow(tb_prediccion),
  "| prob min:", min(tb_prediccion$prob),
  "| prob max:", max(tb_prediccion$prob), "\n"
)

setorder(tb_prediccion, -prob)
dir.create("kaggle", showWarnings = FALSE)

# ------------------------------------------------
# B) Genero SIEMPRE los 11 CSV
# ------------------------------------------------
for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L]
  tb_prediccion[1:envios, Predicted := 1L]

  archivo_kaggle <- paste0(
    "./kaggle/KA", PARAM$experimento, "_", envios, ".csv"
  )

  fwrite(
    tb_prediccion[, list(numero_de_cliente, Predicted)],
    file = archivo_kaggle,
    sep = ","
  )

  cat("CSV generado:", archivo_kaggle, "\n")
}

# ------------------------------------------------
# C) MODO SEGURO
# ------------------------------------------------
if (!isTRUE(PARAM$control$submit_kaggle)) {

  cat("\n============================================================\n")
  cat("PASO 2 EN MODO CONTROL: NO SE REALIZÓ NINGÚN SUBMIT\n")
  cat("Los 11 CSV quedaron generados en ./kaggle/\n")
  cat("\nPara subirlos:\n")
  cat("1) cambiar PARAM$control$submit_kaggle <- FALSE por TRUE\n")
  cat("2) volver a ejecutar SOLAMENTE esta celda PASO 2\n")
  cat("============================================================\n")

} else {

  # ------------------------------------------------
  # D) Reconfirmo acceso antes de enviar
  # ------------------------------------------------
  kaggle_cmd <- Sys.which("kaggle")

  if (nchar(kaggle_cmd) == 0)
    stop("SUBMIT Kaggle: no se encontró la CLI de kaggle.")

  salida_acceso <- suppressWarnings(
    system2(
      kaggle_cmd,
      args = c(
        "competitions", "submissions",
        "-c", PARAM$kaggle$competencia,
        "--page-size", "1",
        "--csv",
        "--quiet"
      ),
      stdout = TRUE,
      stderr = TRUE
    )
  )

  estado_acceso <- attr(salida_acceso, "status")
  if (is.null(estado_acceso)) estado_acceso <- 0

  if (estado_acceso != 0) {
    cat(paste(salida_acceso, collapse = "\n"), "\n")
    stop(
      "SUBMIT Kaggle: no hay acceso a ",
      PARAM$kaggle$competencia,
      ". No se envió ningún archivo."
    )
  }

  cat("\nACCESO KAGGLE OK. INICIO DE LOS 11 SUBMITS.\n")

  # ------------------------------------------------
  # E) Envío real; si uno falla, se detiene
  # ------------------------------------------------
  for (i in seq_along(PARAM$kaggle$cortes)) {

    envios <- PARAM$kaggle$cortes[i]

    archivo_kaggle <- paste0(
      "./kaggle/KA", PARAM$experimento, "_", envios, ".csv"
    )

    mensaje <- paste0(
      "envios=", envios,
      " semilla=", PARAM$semilla_primigenia
    )

    cat("\nSUBMIT:", archivo_kaggle, "\n")

    salida_submit <- suppressWarnings(
      system2(
        kaggle_cmd,
        args = c(
          "competitions", "submit",
          "-c", PARAM$kaggle$competencia,
          "-f", archivo_kaggle,
          "-m", shQuote(mensaje)
        ),
        stdout = TRUE,
        stderr = TRUE
      )
    )

    estado_submit <- attr(salida_submit, "status")
    if (is.null(estado_submit)) estado_submit <- 0

    cat(paste(salida_submit, collapse = "\n"), "\n")

    if (estado_submit != 0) {
      stop(
        "SUBMIT Kaggle FALLÓ en el corte ", envios,
        ". Se detiene el proceso para no seguir enviando."
      )
    }

    if (i < length(PARAM$kaggle$cortes))
      Sys.sleep(30)
  }

  cat("\n============================================================\n")
  cat("SUBMITS FINALIZADOS CORRECTAMENTE\n")
  cat("Experimento:", PARAM$experimento, "\n")
  cat("Competencia:", PARAM$kaggle$competencia, "\n")
  cat("Cantidad de envíos:", length(PARAM$kaggle$cortes), "\n")
  cat("============================================================\n")
}
# Out:
# CONTROL PRE-KAGGLE OK | clientes: 13242 | prob min: 5.055295e-08 | prob max: 0.8411523
# CSV generado: ./kaggle/KA719_LGBM01_800.csv
# CSV generado: ./kaggle/KA719_LGBM01_850.csv
# CSV generado: ./kaggle/KA719_LGBM01_900.csv
# CSV generado: ./kaggle/KA719_LGBM01_950.csv
# CSV generado: ./kaggle/KA719_LGBM01_1000.csv
# CSV generado: ./kaggle/KA719_LGBM01_1050.csv
# CSV generado: ./kaggle/KA719_LGBM01_1100.csv
# CSV generado: ./kaggle/KA719_LGBM01_1150.csv
# CSV generado: ./kaggle/KA719_LGBM01_1200.csv
# CSV generado: ./kaggle/KA719_LGBM01_1250.csv
# CSV generado: ./kaggle/KA719_LGBM01_1300.csv
#
# ACCESO KAGGLE OK. INICIO DE LOS 11 SUBMITS.
#
# SUBMIT: ./kaggle/KA719_LGBM01_800.csv
# 100%|██████████| 142k/142k [00:00<00:00, 386kB/s]
# 44 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_850.csv
# 100%|██████████| 142k/142k [00:00<00:00, 391kB/s]
# 43 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_900.csv
# 100%|██████████| 142k/142k [00:00<00:00, 384kB/s]
# 42 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_950.csv
# 100%|██████████| 142k/142k [00:00<00:00, 376kB/s]
# 41 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_1000.csv
# 100%|██████████| 142k/142k [00:00<00:00, 378kB/s]
# 40 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_1050.csv
# 100%|██████████| 142k/142k [00:00<00:00, 382kB/s]
# 39 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_1100.csv
# 100%|██████████| 142k/142k [00:00<00:00, 377kB/s]
# 38 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_1150.csv
# 100%|██████████| 142k/142k [00:00<00:00, 371kB/s]
# 37 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_1200.csv
# 100%|██████████| 142k/142k [00:00<00:00, 363kB/s]
# 36 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_1250.csv
# 100%|██████████| 142k/142k [00:00<00:00, 370kB/s]
# 35 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# SUBMIT: ./kaggle/KA719_LGBM01_1300.csv
# 100%|██████████| 142k/142k [00:00<00:00, 375kB/s]
# 34 submissions remaining today.
# Successfully submitted to UTN 2026 virtual mgr
#
# ============================================================
# SUBMITS FINALIZADOS CORRECTAMENTE
# Experimento: 719_LGBM01
# Competencia: utn-2026-virtual-mgr
# Cantidad de envíos: 11
# ============================================================

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Sep 19 17:28:38 2026"
